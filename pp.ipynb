# %%
import pandas as pd

# %%
df=pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
uniques=df['Embarked'].unique()

# %%
mapping={x:i for i, x in enumerate(uniques)}

# %%
df['Embarked'].map(mapping)
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 886    0
# 887    0
# 888    0
# 889    1
# 890    2
# Name: Embarked, Length: 891, dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidfVectorizer()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Cabin']=df['Cabin'].fillna('nan')

# %%
tfidf.fit_transform(df['Cabin'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df['Cabin']=tfidf.fit_transform(df['Cabin'])
#
# File c:\Users\Sujan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4322, in DataFrame.__setitem__(self, key, value)
#    4319     self._setitem_array([key], value)
#    4320 else:
#    4321     # set column
# -> 4322     self._set_item(key, value)
#
# File c:\Users\Sujan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4535, in DataFrame._set_item(self, key, value)
#    4525 def _set_item(self, key, value) -> None:
#    4526     """
#    4527     Add series to DataFrame in specified column.
#    4528
#    (...)
#    4533     ensure homogeneity.
#    4534     """
# -> 4535     value, refs = self._sanitize_column(value)
#    4537     if (
#    4538         key in self.columns
# ...

# %%
tfidf.get_feature_names_out()
# Out:
# array(['a10', 'a14', 'a16', 'a19', 'a20', 'a23', 'a24', 'a26', 'a31',
#        'a32', 'a34', 'a36', 'a5', 'a6', 'a7', 'b101', 'b102', 'b18',
#        'b19', 'b20', 'b22', 'b28', 'b3', 'b30', 'b35', 'b37', 'b38',
#        'b39', 'b4', 'b41', 'b42', 'b49', 'b5', 'b50', 'b51', 'b53', 'b55',
#        'b57', 'b58', 'b59', 'b60', 'b63', 'b66', 'b69', 'b71', 'b73',
#        'b77', 'b78', 'b79', 'b80', 'b82', 'b84', 'b86', 'b94', 'b96',
#        'b98', 'c101', 'c103', 'c104', 'c106', 'c110', 'c111', 'c118',
#        'c123', 'c124', 'c125', 'c126', 'c128', 'c148', 'c2', 'c22', 'c23',
#        'c25', 'c26', 'c27', 'c30', 'c32', 'c45', 'c46', 'c47', 'c49',
#        'c50', 'c52', 'c54', 'c62', 'c64', 'c65', 'c68', 'c7', 'c70',
#        'c78', 'c82', 'c83', 'c85', 'c86', 'c87', 'c90', 'c91', 'c92',
#        'c93', 'c95', 'c99', 'd10', 'd11', 'd12', 'd15', 'd17', 'd19',
#        'd20', 'd21', 'd26', 'd28', 'd30', 'd33', 'd35', 'd36', 'd37',
# ...

# %%
df["Cabin"]
# Out:
# 0       nan
# 1       C85
# 2       nan
# 3      C123
# 4       nan
#        ...
# 886     nan
# 887     B42
# 888     nan
# 889    C148
# 890     nan
# Name: Cabin, Length: 891, dtype: object
